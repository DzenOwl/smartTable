# %%
import numpy as np

a = [
    [336, 107], 
    [339, 102], 
    [341, 102], 
    [343, 102], 
    [334, 102], 
    [333, 102], 
    [332, 102], 
    [347, 104], 
    [330, 104], 
    [340, 112], 
    [335, 111], 
    [363, 131], 
    [318, 132], 
    [375, 163], 
    [313, 167], 
    [367, 192], 
    [321, 198], 
    [364, 202], 
    [321, 208], 
    [360, 200], 
    [325, 206], 
    [360, 197], 
    [327, 203], 
    [355, 197], 
    [330, 197], 
    [355, 250], 
    [325, 253], 
    [354, 293], 
    [333, 290], 
    [354, 298], 
    [338, 294], 
    [352, 310], 
    [331, 311]
]

b = [
     [339, 107], 
     [342, 103], 
     [344, 103], 
     [345, 103], 
     [337, 103], 
     [335, 103], 
     [334, 103], 
     [348, 105], 
     [332, 106], 
     [343, 112], 
     [336, 112],
     [364, 133], 
     [320, 136], 
     [371, 164], 
     [314, 168], 
     [365, 190], 
     [324, 198], 
     [362, 199], 
     [324, 207], 
     [358, 195], 
     [329, 206], 
     [358, 192], 
     [329, 202], 
     [356, 196], 
     [331, 197], 
     [353, 249], 
     [333, 249], 
     [354, 295], 
     [339, 294], 
     [353, 301], 
     [342, 299], 
     [353, 312], 
     [336, 310]
]

a = np.array(a)
b = np.array(b)

# %%
shape = np.array([640, 360])
a = np.divide(a, shape).ravel()
b = np.divide(b, shape).ravel()

a
# Out:
# array([0.525     , 0.29722222, 0.5296875 , 0.28333333, 0.5328125 ,
#        0.28333333, 0.5359375 , 0.28333333, 0.521875  , 0.28333333,
#        0.5203125 , 0.28333333, 0.51875   , 0.28333333, 0.5421875 ,
#        0.28888889, 0.515625  , 0.28888889, 0.53125   , 0.31111111,
#        0.5234375 , 0.30833333, 0.5671875 , 0.36388889, 0.496875  ,
#        0.36666667, 0.5859375 , 0.45277778, 0.4890625 , 0.46388889,
#        0.5734375 , 0.53333333, 0.5015625 , 0.55      , 0.56875   ,
#        0.56111111, 0.5015625 , 0.57777778, 0.5625    , 0.55555556,
#        0.5078125 , 0.57222222, 0.5625    , 0.54722222, 0.5109375 ,
#        0.56388889, 0.5546875 , 0.54722222, 0.515625  , 0.54722222,
#        0.5546875 , 0.69444444, 0.5078125 , 0.70277778, 0.553125  ,
#        0.81388889, 0.5203125 , 0.80555556, 0.553125  , 0.82777778,
#        0.528125  , 0.81666667, 0.55      , 0.86111111, 0.5171875 ,
#        0.86388889])

# %%
b
# Out:
# array([0.5296875 , 0.29722222, 0.534375  , 0.28611111, 0.5375    ,
#        0.28611111, 0.5390625 , 0.28611111, 0.5265625 , 0.28611111,
#        0.5234375 , 0.28611111, 0.521875  , 0.28611111, 0.54375   ,
#        0.29166667, 0.51875   , 0.29444444, 0.5359375 , 0.31111111,
#        0.525     , 0.31111111, 0.56875   , 0.36944444, 0.5       ,
#        0.37777778, 0.5796875 , 0.45555556, 0.490625  , 0.46666667,
#        0.5703125 , 0.52777778, 0.50625   , 0.55      , 0.565625  ,
#        0.55277778, 0.50625   , 0.575     , 0.559375  , 0.54166667,
#        0.5140625 , 0.57222222, 0.559375  , 0.53333333, 0.5140625 ,
#        0.56111111, 0.55625   , 0.54444444, 0.5171875 , 0.54722222,
#        0.5515625 , 0.69166667, 0.5203125 , 0.69166667, 0.553125  ,
#        0.81944444, 0.5296875 , 0.81666667, 0.5515625 , 0.83611111,
#        0.534375  , 0.83055556, 0.5515625 , 0.86666667, 0.525     ,
#        0.86111111])

# %%
# !pip install dtaidistance
# Out:
# Collecting dtaidistance
#   Downloading dtaidistance-2.3.2.tar.gz (1.1 MB)
#      |████████████████████████████████| 1.1 MB 5.5 MB/s
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#     Preparing wheel metadata ... done
# Requirement already satisfied: cython>=0.29.6 in /usr/local/lib/python3.7/dist-packages (from dtaidistance) (0.29.24)
# Requirement already satisfied: numpy in /usr/local/lib/python3.7/dist-packages (from dtaidistance) (1.19.5)
# Building wheels for collected packages: dtaidistance
#   Building wheel for dtaidistance (PEP 517) ... done
#   Created wheel for dtaidistance: filename=dtaidistance-2.3.2-cp37-cp37m-linux_x86_64.whl size=1586294 sha256=7c9de95ca4e0eeca084adb3e177b10cb0b6fed58824a7acad53c0aec7afdaf61
#   Stored in directory: /root/.cache/pip/wheels/5e/4a/9a/30f9efb3926e3c2f28231680685b36d0041466a33e4b8f8367
# Successfully built dtaidistance
# Installing collected packages: dtaidistance
# Successfully installed dtaidistance-2.3.2

# %%
from dtaidistance import dtw
from dtaidistance import dtw_visualisation as dtwvis

path = dtw.warping_path(a, b)
dtwvis.plot_warping(a, b, path)
distance = dtw.distance(a, b)
print(distance)
# Out:
# 0.0453998864685588

# %%
c = 1 - np.abs(np.sum(a - b) / 33)
c
# Out:
# 0.9966961279461279

# %%
import numpy as np

a = [
    [336, 107], 
    [339, 102], 
    [341, 102], 
    [343, 102], 
    [334, 102], 
    [333, 102], 
    [332, 102], 
    [347, 104], 
    [330, 104], 
    [340, 112], 
    [335, 111], 
    [363, 131], 
    [318, 132], 
    [375, 163], 
    [313, 167], 
    [367, 192], 
    [321, 198], 
    [364, 202], 
    [321, 208], 
    [360, 200], 
    [325, 206], 
    [360, 197], 
    [327, 203], 
    [355, 197], 
    [330, 197], 
    [355, 250], 
    [325, 253], 
    [354, 293], 
    [333, 290], 
    [354, 298], 
    [338, 294], 
    [352, 310], 
    [331, 311]
]

b = [
    [354, 110], 
    [357, 106], 
    [359, 107], 
    [361, 107], 
    [352, 105], 
    [350, 105], 
    [348, 105], 
    [363, 110], 
    [346, 107], 
    [356, 116], 
    [350, 115], 
    [368, 140], 
    [329, 131], 
    [364, 172], 
    [307, 154], 
    [363, 198], 
    [290, 181], 
    [361, 206], 
    [284, 189], 
    [359, 204], 
    [285, 192], 
    [359, 201], 
    [288, 189], 
    [349, 203], 
    [324, 197], 
    [351, 254], 
    [295, 236], 
    [350, 295], 
    [280, 250], 
    [345, 299], 
    [280, 251], 
    [353, 313], 
    [267, 262]
]

a = np.array(a)
b = np.array(b)

shape = np.array([640, 360])
a = np.divide(a, shape).ravel()
b = np.divide(b, shape).ravel()

path = dtw.warping_path(a, b)
dtwvis.plot_warping(a, b, path)
distance = dtw.distance(a, b)
print(distance)
# Out:
# 0.3230410640021418

# %%
c = 1 - np.abs(np.sum(a - b) / 33)
c
# Out:
# 0.9792297979797979
